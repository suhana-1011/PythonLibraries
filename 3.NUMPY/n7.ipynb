# %%
import numpy as np

# %%
a1=np.array([10,20,30])
print(a1)
# Out:
# [10 20 30]

# %%
np.power(a1,2) # squares the values
# Out:
# array([100, 400, 900])

# %%
np.sum(a1) #adds the elements in array
# Out:
# np.int64(60)

# %%
np.std(a1) #standard deviation values of array
# Out:
# np.float64(8.16496580927726)

# %%
np.mean(a1) #average values of array
# Out:
# np.float64(20.0)

# %%
np.var(a1) #used to check the how far/near the value is from mean value
# Out:
# np.float64(66.66666666666667)

# %%
a2=np.array([1,0,2])

# %%
np.exp(a2) #exponential of the a2 e gives the power fn
# Out:
# array([2.71828183, 1.        , 7.3890561 ])

# %%
np.log(a2) #retrives the value of that power
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2300\4191117931.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(a2) #retrives the value of that power
# array([0.        ,       -inf, 0.69314718])

# %%
a3=np.array([2.71828183, 1.        , 7.3890561 ])
np.log(a3)
# Out:
# array([1., 0., 2.])

# %%
arr1=np.array([10,2,15,5,9,20])
print(arr1)
# Out:
# [10  2 15  5  9 20]

# %%
20 in arr1
# Out:
# True

# %%
np.isin(20,arr1)
# Out:
# array(True)

# %%
np.isin([2,15,8,20],arr1)
# Out:
# array([ True,  True, False,  True])

# %%
np.sort(arr1)
# Out:
# array([ 2,  5,  9, 10, 15, 20])

# %%
np.median(arr1)
# Out:
# np.float64(9.5)

# %%
np.percentile(arr1,25)
np.percentile(arr1,50)
np.percentile(arr1,75)
np.percentile(arr1,100)
# Out:
# np.float64(20.0)

# %%
arr1[np.where(arr1<11)]
# Out:
# array([15, 20])
