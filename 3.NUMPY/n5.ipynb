# %% [markdown]
# ## BRODCASTING ##

# %%
import numpy as np

# %%
l1=[1,2,3,5]
a1=np.array(l1)
print(a1.shape)
c=100
# Out:
# (4,)

# %%
a1+c
# Out:
# array([101, 102, 103, 105])

# %%
l2=[1,2,3,4]
a2=np.array(l2)
print(a2.shape)
c=100
# Out:
# (4,)

# %%
a1+a2
# Out:
# array([2, 4, 6, 9])

# %%
a3=np.array([100,200,300,400])

# %%
a2+a3
# Out:
# array([101, 202, 303, 404])

# %%
a4=np.array([100,200,300,400])
print(a4)
print(a4.shape)
# Out:
# [100 200 300 400]
# (4,)

# %%
a1+a4
# Out:
# array([101, 202, 303, 405])

# %%
a5=np.array([[[8],[5]],[[2],[1]],[[23],[36]]])
print(a5)
print(a5.shape)
# Out:
# [[[ 8]
#   [ 5]]
#
#  [[ 2]
#   [ 1]]
#
#  [[23]
#   [36]]]
# (3, 2, 1)

# %%
a4+a5
# Out:
# array([[[108, 208, 308, 408],
#         [105, 205, 305, 405]],
#
#        [[102, 202, 302, 402],
#         [101, 201, 301, 401]],
#
#        [[123, 223, 323, 423],
#         [136, 236, 336, 436]]])
