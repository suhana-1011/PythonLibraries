# %%
import pandas as pd

# %%
df=pd.read_csv("student_performance_dirty .csv")

# %%
df.head()
# Out:
#    StudentID  Gender   Age  StudyHours  Attendance  Marks Grade Pass
# 0          1    Male  20.0           2          80   65.0     B  Yes
# 1          2  Female  21.0           4          90   85.0     A  Yes
# 2          3    Male  19.0           3          75   58.0     C  Yes
# 3          4  Female  22.0           5          95   92.0     A  Yes
# 4          5    Male   NaN           1          60   40.0     D   No

# %%
df.shape
# Out:
# (12, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   12 non-null     int64
#  1   Gender      12 non-null     str
#  2   Age         11 non-null     float64
#  3   StudyHours  12 non-null     int64
#  4   Attendance  12 non-null     int64
#  5   Marks       11 non-null     float64
#  6   Grade       12 non-null     str
#  7   Pass        12 non-null     str
# dtypes: float64(2), int64(3), str(3)
# memory usage: 1007.0 bytes

# %%
Agee=df['Age'].mean()

# %%
df['Age']=df['Age'].fillna(Agee)

# %%
df['Age']=df['Age'].round(1)

# %%
df.loc[df['Marks'] == 150, 'Marks'] = df['Marks'].median()

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].median())

# %%
df
# Out:
#     StudentID  Gender   Age  StudyHours  Attendance  Marks Grade Pass
# 0           1    Male  20.0           2          80   65.0     B  Yes
# 1           2  Female  21.0           4          90   85.0     A  Yes
# 2           3    Male  19.0           3          75   58.0     C  Yes
# 3           4  Female  22.0           5          95   92.0     A  Yes
# 4           5    Male  20.6           1          60   40.0     D   No
# 5           6  Female  20.0           2          82   82.0     B  Yes
# 6           7    Male  21.0           6          98   96.0     A  Yes
# 7           8  Female  19.0           3          78   68.0     B  Yes
# 8           9    Male  20.0           2          70   55.0     C  Yes
# 9          10  Female  22.0           4          88   82.0     A  Yes
# 10         10  Female  22.0           4          88   82.0     A  Yes
# 11         11    Male  21.0           8         100   82.0     A  Yes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   12 non-null     int64
#  1   Gender      12 non-null     str
#  2   Age         12 non-null     float64
#  3   StudyHours  12 non-null     int64
#  4   Attendance  12 non-null     int64
#  5   Marks       12 non-null     float64
#  6   Grade       12 non-null     str
#  7   Pass        12 non-null     str
# dtypes: float64(2), int64(3), str(3)
# memory usage: 1007.0 bytes

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      6
# Female    6
# Name: count, dtype: int64

# %%
df
# Out:
#     StudentID  Gender   Age  StudyHours  Attendance  Marks Grade Pass
# 0           1    Male  20.0           2          80   65.0     B  Yes
# 1           2  Female  21.0           4          90   85.0     A  Yes
# 2           3    Male  19.0           3          75   58.0     C  Yes
# 3           4  Female  22.0           5          95   92.0     A  Yes
# 4           5    Male  20.6           1          60   40.0     D   No
# 5           6  Female  20.0           2          82   82.0     B  Yes
# 6           7    Male  21.0           6          98   96.0     A  Yes
# 7           8  Female  19.0           3          78   68.0     B  Yes
# 8           9    Male  20.0           2          70   55.0     C  Yes
# 9          10  Female  22.0           4          88   82.0     A  Yes
# 10         10  Female  22.0           4          88   82.0     A  Yes
# 11         11    Male  21.0           8         100   82.0     A  Yes

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# What is the gender distribution of students?are male and femal students equally represented

# %%
plt.figure(figsize=(4,5))
sns.countplot(data=df,x='Gender')
#plt.title('Distribution of emps according to their status')
#plt.ylabel('no of emps')
plt.show()

# %% [markdown]
# The gender distribution is 50-50.YEes it is Equal

# %% [markdown]
# 2.What percentage of students passed and faile?Provide a quick summary for management

# %%
c=df['Pass'].value_counts()
print(c.index)
print(c.values)
# Out:
# Index(['Yes', 'No'], dtype='str', name='Pass')
# [11  1]

# %%
plt.pie(x=c.values, labels=c.index, autopct='%1.1f%%')
plt.title('Percentage of Pass and Fail')
plt.show()

# %%
l=df['Marks']
s=pd.Series(l)
sns.boxplot(x=s)
# Out:
# <Axes: xlabel='Marks'>

# %% [markdown]
# 3.

# %%
plt.figure(figsize=(4,5))
c=sns.barplot(data=df,x='Grade',y='Marks',errorbar=None,estimator='mean')
#c.bar_label(c.containers[0],fmt='%.1f')
#plt.title('Avg fare by gender')
plt.yticks(range(0,20,2))
plt.show()

# %% [markdown]
# ## 4

# %%
sns.scatterplot(data=df,x='StudyHours',y='Marks')
# Out:
# <Axes: xlabel='StudyHours', ylabel='Marks'>

# %%
df
# Out:
#     StudentID  Gender   Age  StudyHours  Attendance  Marks Grade Pass
# 0           1    Male  20.0           2          80   65.0     B  Yes
# 1           2  Female  21.0           4          90   85.0     A  Yes
# 2           3    Male  19.0           3          75   58.0     C  Yes
# 3           4  Female  22.0           5          95   92.0     A  Yes
# 4           5    Male  20.6           1          60   40.0     D   No
# 5           6  Female  20.0           2          82   82.0     B  Yes
# 6           7    Male  21.0           6          98   96.0     A  Yes
# 7           8  Female  19.0           3          78   68.0     B  Yes
# 8           9    Male  20.0           2          70   55.0     C  Yes
# 9          10  Female  22.0           4          88   82.0     A  Yes
# 10         10  Female  22.0           4          88   82.0     A  Yes
# 11         11    Male  21.0           8         100   82.0     A  Yes

# %% [markdown]
# 5.

# %%
fc=sns.FacetGrid(df,col='Gender',aspect=1.5)
fc.map_dataframe(sns.barplot,x='Gender',y='Pass',estimator='count',errorbar=None)
plt.show()

# %% [markdown]
# 6

# %%
plt.figure(figsize=(5,4))
sns.histplot(df['Marks'], bins=8, kde=True)
plt.title("Distribution of Marks")
plt.show()

# %% [markdown]
# 7

# %%
plt.figure(figsize=(5,4))
sns.boxplot(y=df['Marks'])
plt.title("Box Plot of Marks")
plt.show()

# %% [markdown]
# 8

# %%
plt.figure(figsize=(4,4))
sns.barplot(data=df, x='Gender', y='Attendance', estimator='mean', errorbar=None)
plt.title("Average Attendance by Gender")
plt.show()
